# %%
import os
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# %%
from yolo import YOLO
from PIL import Image

# %%
image = Image.open('1.jpg')
yolo_d = YOLO()
yolo_d.detect_image(image)
# Out:
# model_data/yolo.h5 model, anchors, and classes loaded.
# (416, 416, 3)
# Found 4 boxes for img
# bottle 0.42 (311, 390) (468, 735)
# bottle 0.76 (684, 370) (833, 758)
# bottle 0.85 (123, 370) (280, 751)
# bottle 0.89 (496, 389) (648, 736)
# 10.390014399999927
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000 at 0x205BC14A608>
